# %% [markdown]
# <a href="https://colab.research.google.com/github/its-emile/memory-safe-agent/blob/main/Memory_safe_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Memory-safe (blind) agentic simulation
#
# Paper draft link: https://docs.google.com/document/d/1FwzQNX0IdaevenZVpwQ6Ph_1BA0fdE8OeqEkKx8-dfo/edit?tab=t.0
#
# ## Problem Statement
# By default, any data an AI agent context can fetch has a risk of exposure to all other tools in that agent. The security measure to limit this risk tends to be authenticating most tools, but this requirement is often an oversimplification due to confering complete trust to the agent and the other tools (whereas some tools or their outputs/data may be less trusted than others, and may expose inputs to wider access than strictly the current user).
#
# ##Proposed solution
# An LLM-based agent application can solve a task where tools exchange data, without revealing any of the intermediate data between tool calls to the LLM.
#
# Furthermore, a policy can strictly govern permissions to exchange data between tools, guarding against the LLM's unbounded data flow.
#
# ## Demonstration
# In this example simulation, a Slack LLM agent fetches and responds with a confidential insight about a user, using a condition processed on a confidential record. The LLM sees neither the record, nor the resulting insight.
#
# You may apply this to your own scenarios, letting the agent manage calls to privileged tools while preventing any exposure, for example, of the tools' authentication steps or sensitive or untrusted intermediate data.

# %%
from google.colab import userdata
from google import genai
from abc import ABC, abstractmethod
from pydantic import BaseModel

# Use Gemini for now since it has a free API.
# Ideally we would end up using two models from different labs.
GEMINI_CLIENT = genai.Client(api_key=userdata.get("GOOGLE_API_KEY"))


class Model(ABC):
    @abstractmethod
    def model_json(self, message: str) -> str:
        pass

class Gemini(Model):
    def __init__(self):
        self.client = GEMINI_CLIENT

    def model_json(self, message: str, output_schema: str) -> str:
      """Model must generate within the specified schema"""
      print(f"#### LLM CALL (length: {len(message)})")
      return self.client.models.generate_content(
          model = "gemini-2.0-flash",
          contents = message,
          config={
            'response_mime_type': 'application/json',
            'response_schema': output_schema,
          },
      )

# %%
import random
import time
import numpy as np
from dataclasses import dataclass
from typing import List, Dict, Any, Tuple, Optional, Union
import json

AGENT_TEMPLATE="""
You are a highly capable agent, but operating in a blind environment. You have access to the tools below, but won't see the data I/O between them:
{tools}

To fulfill your task below, you will write an execution flow in json as a series of {{method_name, parameter_dict, call_id, out_params}}
Rule 1: You will not see the output data of each call but you can reference any output parameter name by formatting a variable name as call_id:out_param_name
Rule 2: For security reasons, the method "_" must be used for any literals; any other method calls will fail if a parameter_dict contains any literals: must set params as references to call_id:out_param_name
Rule 3: For security reasons, the last method must have "method_name":"result", "call_id":"result" and "parameter_dict" must contain all information the user may need regarding your task completion
Rule 4: The constraints in each tool above are hard constraints and must be respected: you must not use parameter references unless the tools above permit them with exact parameter names matching.
Rule 5: You must use integers for call_id and must start with method _ having this integer call_id: {initial_call_id}
Rule 6: You should only call _ once (group all the literals).

Your new task to fulfill is:
<usertask>
{task}
</usertask>

Now carefully design an execution flow for this task, and print it only as valid json-formatted as per the example, and don't forget to pass to each method call all the parameters it requires.
Note: You've already executed some prior calls below on the user's behalf. Continue the execution flow.
{prior_calls}
"""

SCHEMA_EXEC_FLOW = {
                "type": "array",
                "items": {
                  "type": "object",
                  "properties": {
                    "method_name": {
                      "type": "string",
                    },
                    "call_id": {
                      "type": "integer",
                    },
                    "out_params": {
                      "type": "array",
                      "items": {
                        "type": "string",
                      }
                    },
                    "parameter_dict": {
                      "type": "array",
                      "items": {
                        "type": "object",
                        "properties": {
                          "param_name": {
                            "type": "string",
                          },
                          "param_source": {
                            "type": "string",
                          },
                        },
                      }
                    }
                  },
                  "required": ["method_name","call_id"],
                },
              }

class MemorySafeAgent(ABC):
  def __init__(self, tools_policy: str):
    self.model = Gemini()
    self.tools = tools_policy
    self.call_results={}
    self.call_history_safe={}

  def process_task(self, task:str):
    instructions = AGENT_TEMPLATE.format(
          tools = self.tools,
          task = task,
          initial_call_id = len(self.call_results),
          prior_calls = self.call_history_safe)
    print("Model instructions ",instructions)
    generated_flow = Gemini().model_json(
      instructions,
      output_schema = SCHEMA_EXEC_FLOW
    ).text
    print("Model generated flow:",generated_flow)
    self.current_execution_flow = json.loads(generated_flow)

    for step in self.current_execution_flow:
      if step["method_name"]=="_":
        self.call_results[step["call_id"]]={}
        for p in self.current_execution_flow[0]["parameter_dict"]:
          self.call_results[step["call_id"]][p["param_name"]] = p["param_source"]
        self.call_history_safe[step["call_id"]]={"method_name": "_", "parameter_dict": step["parameter_dict"]}
      else:
        self.call_history_safe[step["call_id"]]={"method_name": step["method_name"], "parameter_dict": step["parameter_dict"]}

        if step["method_name"]=="result":
          self.call_results[step["call_id"]] = self.memory_fetch_unsafe(step["parameter_dict"])
          return self.call_results[step["call_id"]]
        else:
          self.call_results[step["call_id"]] = self.method_call(step["method_name"], step["parameter_dict"])


  def method_call(self, method_name: str, params: Dict[str, Any]):
    if method_name not in self.tools.keys():
      raise ValueError(f"Unknown method name: {method_name}")

    param_values = self.memory_fetch_safe(method_name, params)

    print(f"Calling {method_name} with {param_values}")

    method = getattr(self, method_name)
    res = method(**param_values)

    print(f"Result: {res}")
    return res

  def memory_fetch_safe(self, method_name: str, param_dict: list(Dict[str, Any])) -> Dict[str, Any]:
    for p in param_dict:
      # verify this sink is allowed by the source the agent is trying to use
      source_call, source_param = p['param_source'].split(":")
      source_method = self.call_history_safe[int(source_call)]["method_name"]
      print(f"verifying param ({p['param_name']}) access policy for {method_name} (source: {source_method}:{source_param})")

      if source_method != "_" and f'{method_name}:{p["param_name"]}' not in self.tools[source_method]["out_params_allowed_sinks"][source_param]:
          raise ValueError(f"{source_method} does not authorize {method_name} to read {source_param} to serve as {p['param_name']}")

      if f'{source_method}:{source_param}' not in self.tools[method_name]["in_params_allowed_sources"][p['param_name']]:
        raise ValueError(f"{method_name} does not authorize reading {source_param} from {source_method}")

    # params are permitted by the specified method and their source.
    return self.memory_fetch_unsafe(param_dict)

  def memory_fetch_unsafe(self, param_dict: list(Dict[str, Any])):
    # gets specified output values but not inherently memory safe, requires outer validation
    params={}
    for p in param_dict:
      print(f'loading {p["param_name"]} = {p["param_source"]}')

      p_source, p_name = p["param_source"].split(":")

      if int(p_source) not in self.call_results.keys():
        raise ValueError(f"Unknown source call id: {p_source}")

      if p_name not in self.call_results[int(p_source)].keys():
        raise ValueError(f"Unknown output from {self.call_history_safe[int(p_source)]['method_name']}: {p_name}")

      value = self.call_results[int(p_source)][p_name]
      params[p["param_name"]] = value
      print(f'loaded {p["param_name"]} from {p["param_source"]} = {value}')
    return params

  # simulated tools for testing purposes
  def fetch_db(self, query) -> str:
    print(f"fetching user by query: {query}")
    return {"user_record":{"name":"jack smith","license_expiration":"2026-04-30"}} # simulated

  def license_check(self, user_record) -> bool:
    from datetime import datetime
    print(f"verifying license date {user_record['license_expiration']}")
    parsed_datetime = datetime.strptime(user_record["license_expiration"], "%Y-%m-%d")
    return {"license_status":parsed_datetime > datetime.now()}

  def post_message(self, message_template: str, message_data: str | None) -> bool:
    f_msg = message_template.format(message_data)
    print(f"posting message to slack: {f_msg}")
    #... slack integration would follow
    return {"slack_successful":True} # simulated

# %%
# EXAMPLE USAGE:

# TOOL_LIST must include for each tool:
# - where may it read input parameters (e.g. from _ if values/literals direct from LLM should be allowed)
# - what its output parameters are and where they may be accessed from


TOOLS_POLICY = {
    "fetch_db": {
        "description": "fetch user record from database",
        "in_params_allowed_sources": {
            "query": ["_:query"]
        },
        "out_params_allowed_sinks": {
            "user_record": ["license_check:user_record"]
        }
    },
    "license_check": {
        "description": "check if license expiration date is in the future",
        "in_params_allowed_sources": {
            "user_record": ["fetch_db:user_record"],
        },
        "out_params_allowed_sinks": {
            "license_status": ["post_message:message_data"]
        }
    },
    "post_message": {
        "description": "formats a message with one data input (eg: 'the time is {}') and posts it to slack",
        "in_params_allowed_sources": {
            "message_data": ["license_check:license_status"],
            "message_template": ["_:message_template"]
        },
        "out_params_allowed_sinks": {
            "slack_successful": ["result:slack_successful"]
        }
    },
    "display_error": {
        "description": "notify the user in case the workflow cannot meet the request",
        "in_params_allowed_sources": {
            "err_message": ["_:err_message"]
        },
        "out_params_allowed_sinks": {
            "err_message": ["result:err_message"]
        }
    }
}

a = MemorySafeAgent(TOOLS_POLICY)

# %%
a.process_task("tell me on slack whether our top user's license is still current")
# Out:
# Model instructions
# You are a highly capable agent, but operating in a blind environment. You have access to the tools below, but won't see the data I/O between them:
# {'fetch_db': {'description': 'fetch user record from database', 'in_params_allowed_sources': {'query': ['_:query']}, 'out_params_allowed_sinks': {'user_record': ['license_check:user_record']}}, 'license_check': {'description': 'check if license expiration date is in the future', 'in_params_allowed_sources': {'user_record': ['fetch_db:user_record']}, 'out_params_allowed_sinks': {'license_status': ['post_message:message_data']}}, 'post_message': {'description': "formats a message with one data input (eg: 'the time is {}') and posts it to slack", 'in_params_allowed_sources': {'message_data': ['license_check:license_status'], 'message_template': ['_:message_template']}, 'out_params_allowed_sinks': {'slack_successful': ['result:slack_successful']}}, 'display_error': {'description': 'notify the user in case the workflow cannot meet the request', 'in_params_allowed_sources': {'err_message': ['_:err_message']}, 'out_params_allowed_sinks': {'err_message': ['result:err_message']}}}
#
# To fulfill your task below, you will write an execution flow in json as a series of {method_name, parameter_dict, call_id, out_params}
# Rule 1: You will not see the output data of each call but you can reference any output parameter name by formatting a variable name as call_id:out_param_name
# Rule 2: For security reasons, the method "_" must be used for any literals; any other method calls will fail if a parameter_dict contains any literals: must set params as references to call_id:out_param_name
# Rule 3: For security reasons, the last method must have "method_name":"result", "call_id":"result" and "parameter_dict" must contain all information the user may need regarding your task completion
# Rule 4: The constraints in each tool above are hard constraints and must be respected: you must not use parameter references unless the tools above permit them with exact parameter names matching.
# Rule 5: You must use integers for call_id and must start with method _ having this integer call_id: 0
# Rule 6: You should only call _ once (group all the literals).
#
# Your new task to fulfill is:
# <usertask>
# tell me on slack whether our top user's license is still current
# </usertask>
#
# Now carefully design an execution flow for this task, and print it only as valid json-formatted as per the example, and don't forget to pass to each method call all the parameters it requires.
# Note: You've already executed some prior calls below on the user's behalf. Continue the execution flow.
# {}
#
# #### LLM CALL (length: 2615)
# Model generated flow: [
#   {
#     "method_name": "_",
#     "call_id": 0,
#     "out_params": [
#       "query",
#       "message_template"
#     ],
#     "parameter_dict": [
#       {
#         "param_name": "query",
#         "param_source": "SELECT * FROM users WHERE user_id = (SELECT user_id FROM users ORDER BY total_contribution DESC LIMIT 1)"
#       },
#       {
#         "param_name": "message_template",
#         "param_source": "The top user's license is {}"
#       }
#     ]
#   },
#   {
#     "method_name": "fetch_db",
#     "call_id": 1,
#     "out_params": [
#       "user_record"
#     ],
#     "parameter_dict": [
#       {
#         "param_name": "query",
#         "param_source": "0:query"
#       }
#     ]
#   },
#   {
#     "method_name": "license_check",
#     "call_id": 2,
#     "out_params": [
#       "license_status"
#     ],
#     "parameter_dict": [
#       {
#         "param_name": "user_record",
#         "param_source": "1:user_record"
#       }
#     ]
#   },
#   {
#     "method_name": "post_message",
#     "call_id": 3,
#     "out_params": [
#       "slack_successful"
#     ],
#     "parameter_dict": [
#       {
#         "param_name": "message_data",
#         "param_source": "2:license_status"
#       },
#       {
#         "param_name": "message_template",
#         "param_source": "0:message_template"
#       }
#     ]
#   },
#   {
#     "method_name": "result",
#     "call_id": 4,
#     "parameter_dict": [
#       {
#         "param_name": "slack_successful",
#         "param_source": "3:slack_successful"
#       }
#     ]
#   }
# ]
# verifying param (query) access policy for fetch_db (source: _:query)
# loading query = 0:query
# loaded query from 0:query = SELECT * FROM users WHERE user_id = (SELECT user_id FROM users ORDER BY total_contribution DESC LIMIT 1)
# Calling fetch_db with {'query': 'SELECT * FROM users WHERE user_id = (SELECT user_id FROM users ORDER BY total_contribution DESC LIMIT 1)'}
# fetching user by query: SELECT * FROM users WHERE user_id = (SELECT user_id FROM users ORDER BY total_contribution DESC LIMIT 1)
# Result: {'user_record': {'name': 'jack smith', 'license_expiration': '2026-04-30'}}
# verifying param (user_record) access policy for license_check (source: fetch_db:user_record)
# loading user_record = 1:user_record
# loaded user_record from 1:user_record = {'name': 'jack smith', 'license_expiration': '2026-04-30'}
# Calling license_check with {'user_record': {'name': 'jack smith', 'license_expiration': '2026-04-30'}}
# verifying license date 2026-04-30
# Result: {'license_status': True}
# verifying param (message_data) access policy for post_message (source: license_check:license_status)
# verifying param (message_template) access policy for post_message (source: _:message_template)
# loading message_data = 2:license_status
# loaded message_data from 2:license_status = True
# loading message_template = 0:message_template
# loaded message_template from 0:message_template = The top user's license is {}
# Calling post_message with {'message_data': True, 'message_template': "The top user's license is {}"}
# posting message to slack: The top user's license is True
# Result: {'slack_successful': True}
# loading slack_successful = 3:slack_successful
# loaded slack_successful from 3:slack_successful = True
# {'slack_successful': True}

# %%
a.process_task("post our top user's name to slack")
# Out:
# Model instructions
# You are a highly capable agent, but operating in a blind environment. You have access to the tools below, but won't see the data I/O between them:
# {'fetch_db': {'description': 'fetch user record from database', 'in_params_allowed_sources': {'query': ['_:query']}, 'out_params_allowed_sinks': {'user_record': ['license_check:user_record']}}, 'license_check': {'description': 'check if license expiration date is in the future', 'in_params_allowed_sources': {'user_record': ['fetch_db:user_record']}, 'out_params_allowed_sinks': {'license_status': ['post_message:message_data']}}, 'post_message': {'description': "formats a message with one data input (eg: 'the time is {}') and posts it to slack", 'in_params_allowed_sources': {'message_data': ['license_check:license_status'], 'message_template': ['_:message_template']}, 'out_params_allowed_sinks': {'slack_successful': ['result:slack_successful']}}, 'display_error': {'description': 'notify the user in case the workflow cannot meet the request', 'in_params_allowed_sources': {'err_message': ['_:err_message']}, 'out_params_allowed_sinks': {'err_message': ['result:err_message']}}}
#
# To fulfill your task below, you will write an execution flow in json as a series of {method_name, parameter_dict, call_id, out_params}
# Rule 1: You will not see the output data of each call but you can reference any output parameter name by formatting a variable name as call_id:out_param_name
# Rule 2: For security reasons, the method "_" must be used for any literals; any other method calls will fail if a parameter_dict contains any literals: must set params as references to call_id:out_param_name
# Rule 3: For security reasons, the last method must have "method_name":"result", "call_id":"result" and "parameter_dict" must contain all information the user may need regarding your task completion
# Rule 4: The constraints in each tool above are hard constraints and must be respected: you must not use parameter references unless the tools above permit them with exact parameter names matching.
# Rule 5: You must use integers for call_id and must start with method _ having this integer call_id: 10
# Rule 6: You should only call _ once (group all the literals).
#
# Your new task to fulfill is:
# <usertask>
# post our top user's name to slack
# </usertask>
#
# Now carefully design an execution flow for this task, and print it only as valid json-formatted as per the example, and don't forget to pass to each method call all the parameters it requires.
# Note: You've already executed some prior calls below on the user's behalf. Continue the execution flow.
# {0: {'method_name': '_', 'parameter_dict': [{'param_name': 'query', 'param_source': 'SELECT * FROM users WHERE user_id = (SELECT user_id FROM users ORDER BY total_contribution DESC LIMIT 1)'}, {'param_name': 'message_template', 'param_source': "The top user's license is {}"}]}, 1: {'method_name': 'fetch_db', 'parameter_dict': [{'param_name': 'query', 'param_source': '0:query'}]}, 2: {'method_name': 'license_check', 'parameter_dict': [{'param_name': 'user_record', 'param_source': '1:user_record'}]}, 3: {'method_name': 'post_message', 'parameter_dict': [{'param_name': 'message_data', 'param_source': '2:license_status'}, {'param_name': 'message_template', 'param_source': '0:message_template'}]}, 4: {'method_name': 'result', 'parameter_dict': [{'param_name': 'slack_successful', 'param_source': '3:slack_successful'}]}, 5: {'method_name': '_', 'parameter_dict': [{'param_name': 'query', 'param_source': 'SELECT * FROM users ORDER BY total_contribution DESC LIMIT 1'}, {'param_name': 'message_template', 'param_source': "The top user's license is {}"}]}, 6: {'method_name': 'fetch_db', 'parameter_dict': [{'param_name': 'query', 'param_source': '5:query'}]}, 7: {'method_name': 'license_check', 'parameter_dict': [{'param_name': 'user_record', 'param_source': '6:user_record'}]}, 8: {'method_name': 'post_message', 'parameter_dict': [{'param_name': 'message_data', 'param_source': '7:license_status'}, {'param_name': 'message_template', 'param_source': '5:message_template'}]}, 9: {'method_name': 'result', 'parameter_dict': [{'param_name': 'slack_successful', 'param_source': '8:slack_successful'}]}}
#
# #### LLM CALL (length: 4189)
# Model generated flow: [
#   {
#     "method_name": "_",
#     "call_id": 10,
#     "parameter_dict": [
#       {
#         "param_name": "query",
#         "param_source": "SELECT * FROM users ORDER BY total_contribution DESC LIMIT 1"
#       },
#       {
#         "param_name": "message_template",
#         "param_source": "The top user's license is {}"
#       }
#     ]
#   },
#   {
#     "method_name": "fetch_db",
#     "call_id": 11,
#     "parameter_dict": [
#       {
#         "param_name": "query",
#         "param_source": "10:query"
#       }
#     ]
#   },
#   {
#     "method_name": "license_check",
#     "call_id": 12,
#     "parameter_dict": [
#       {
#         "param_name": "user_record",
#         "param_source": "11:user_record"
#       }
#     ]
#   },
#   {
#     "method_name": "post_message",
#     "call_id": 13,
#     "parameter_dict": [
#       {
#         "param_name": "message_data",
#         "param_source": "12:license_status"
#       },
#       {
#         "param_name": "message_template",
#         "param_source": "10:message_template"
#       }
#     ]
#   },
#   {
#     "method_name": "result",
#     "call_id": 14,
#     "parameter_dict": [
#       {
#         "param_name": "slack_successful",
#         "param_source": "13:slack_successful"
#       }
#     ]
#   }
# ]
# verifying param (query) access policy for fetch_db (source: _:query)
# loading query = 10:query
# loaded query from 10:query = SELECT * FROM users ORDER BY total_contribution DESC LIMIT 1
# Calling fetch_db with {'query': 'SELECT * FROM users ORDER BY total_contribution DESC LIMIT 1'}
# fetching user by query: SELECT * FROM users ORDER BY total_contribution DESC LIMIT 1
# Result: {'user_record': {'name': 'jack smith', 'license_expiration': '2026-04-30'}}
# verifying param (user_record) access policy for license_check (source: fetch_db:user_record)
# loading user_record = 11:user_record
# loaded user_record from 11:user_record = {'name': 'jack smith', 'license_expiration': '2026-04-30'}
# Calling license_check with {'user_record': {'name': 'jack smith', 'license_expiration': '2026-04-30'}}
# verifying license date 2026-04-30
# Result: {'license_status': True}
# verifying param (message_data) access policy for post_message (source: license_check:license_status)
# verifying param (message_template) access policy for post_message (source: _:message_template)
# loading message_data = 12:license_status
# loaded message_data from 12:license_status = True
# loading message_template = 10:message_template
# loaded message_template from 10:message_template = The top user's license is {}
# Calling post_message with {'message_data': True, 'message_template': "The top user's license is {}"}
# posting message to slack: The top user's license is True
# Result: {'slack_successful': True}
# loading slack_successful = 13:slack_successful
# loaded slack_successful from 13:slack_successful = True
# {'slack_successful': True}
